# %%
from PIL import Image
import numpy as np

# Path to the image file
image_path = "assets/data/imagenette/700/36/activations/images/36_3768_0_2-876968_0-570753_1-642038.png"

# Open the image
image = Image.open(image_path)

# %%
a = np.array(image)

# %%
# Path to the .npy file
file_path = "assets/data/imagenette/700/36/activations/raw_data/36_3768_0_2-876968_0-570753_1-642038.npy"

# Load the .npy file
loaded_array = np.load(file_path)

# Print the loaded array
print("Loaded Array:")
print(loaded_array)
# Out:
# Loaded Array:
# [[1.8207895  2.1975338  2.11191    ... 0.8446785  0.878928   0.9131775 ]
#  [1.4097953  2.1461596  2.0262864  ... 0.82755375 0.86180323 0.878928  ]
#  [0.878928   1.8379141  1.8892884  ... 0.810429   0.82755375 0.82755375]
#  ...
#  [1.4782944  1.4782944  1.4440448  ... 1.4611696  1.4611696  1.4440448 ]
#  [1.5125438  1.5296686  1.5125438  ... 1.5125438  1.4611696  1.4782944 ]
#  [1.4440448  1.4440448  1.4440448  ... 1.3926706  1.3926706  1.42692   ]]

# %%
import plotly.express as px
import numpy as np
img_rgb = np.array(loaded_array)
print(img_rgb)
fig = px.imshow(img_rgb)
fig.show()
# Out:
# [[1.8207895  2.1975338  2.11191    ... 0.8446785  0.878928   0.9131775 ]
#  [1.4097953  2.1461596  2.0262864  ... 0.82755375 0.86180323 0.878928  ]
#  [0.878928   1.8379141  1.8892884  ... 0.810429   0.82755375 0.82755375]
#  ...
#  [1.4782944  1.4782944  1.4440448  ... 1.4611696  1.4611696  1.4440448 ]
#  [1.5125438  1.5296686  1.5125438  ... 1.5125438  1.4611696  1.4782944 ]
#  [1.4440448  1.4440448  1.4440448  ... 1.3926706  1.3926706  1.42692   ]]
# ...

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
